# %% [markdown]
# 공공데이타 - https://www.data.go.kr/dataset/15012005/fileData.do

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("소상공인시장진흥공단_상가(상권)정보_서울_202403.csv", dtype={2: str})

# %%
df.shape
# Out:
# (475236, 39)

# %%
df.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
# 컬럼 정리
columns = ['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', 
           '시도명', '시군구명', '행정동명', '법정동명', '도로명주소', 
           '경도', '위도']
df = df[columns].copy()
df.shape
# Out:
# (475236, 11)

# %%
df["시군구명"].unique()
# Out:
# array(['광진구', '중구', '노원구', '양천구', '강서구', '송파구', '구로구', '강남구', '영등포구',
#        '금천구', '마포구', '성동구', '중랑구', '서초구', '동작구', '은평구', '동대문구', '서대문구',
#        '도봉구', '종로구', '관악구', '성북구', '강동구', '용산구', '강북구'], dtype=object)

# %%
df['상호명_소문자'] = df['상호명'].str.lower()

# %%
df.columns
# Out:
# Index(['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '시도명', '시군구명', '행정동명',
#        '법정동명', '도로명주소', '경도', '위도', '상호명_소문자'],
#       dtype='object')

# %%
df_31 = df[df["상호명_소문자"].str.contains('배스킨라빈스|베스킨라빈스|baskinrobbins|던킨|dunkin')].copy()

# %%
df_31.shape
# Out:
# (398, 12)

# %%
df_31.loc[df_31["상호명_소문자"].str.contains("배스킨라빈스|베스킨라빈스|baskinrobbins"), "브랜드명"] = "배스킨라빈스"
df_31.loc[df_31["상호명_소문자"].str.contains("던킨|dunkin"), "브랜드명"] = "던킨도너츠"

# %%
df_31[["상호명", "브랜드명"]].head()
# Out:
#                  상호명    브랜드명
# 1970  비알배스킨라빈스한남HIVE  배스킨라빈스
# 4826   비알배스킨라빈스동부이촌점  배스킨라빈스
# 8942      배스킨라빈스상계역점  배스킨라빈스
# 9497      배스킨라빈스길동역점  배스킨라빈스
# 9808   비알배스킨라빈스서울대병원  배스킨라빈스

# %%
df_31.columns
# Out:
# Index(['상호명', '상권업종대분류명', '상권업종중분류명', '상권업종소분류명', '시도명', '시군구명', '행정동명',
#        '법정동명', '도로명주소', '경도', '위도', '상호명_소문자', '브랜드명'],
#       dtype='object')

# %%
df_31 = df_31[df_31['상권업종대분류명'] == '음식']

# %%
df_31.shape
# Out:
# (395, 13)

# %%
brand_count = df_31["브랜드명"].value_counts() # "브랜드명"의 빈도수
brand_count
# Out:
# 브랜드명
# 배스킨라빈스    291
# 던킨도너츠     104
# Name: count, dtype: int64

# %%
relative_frequency = df_31["브랜드명"].value_counts(normalize=True)  # normalize=True 빈도수의 비율
relative_frequency
# Out:
# 브랜드명
# 배스킨라빈스    0.736709
# 던킨도너츠     0.263291
# Name: proportion, dtype: float64

# %%
plt.rc('font', family='Malgun Gothic')

# %%
relative_frequency.plot.barh();

# %%
brand_count
# Out:
# 브랜드명
# 배스킨라빈스    291
# 던킨도너츠     104
# Name: count, dtype: int64

# %%
brand_count.index
# Out:
# Index(['배스킨라빈스', '던킨도너츠'], dtype='object', name='브랜드명')

# %%
g = sns.countplot(data=df_31, x="브랜드명")

for i, val in enumerate(brand_count.index):
    g.text(x=i, y=brand_count.iloc[i], s=brand_count.iloc[i])

# %%
plt.figure(figsize=(15, 4))
g = sns.countplot(data=df_31, x="시군구명", hue="브랜드명")

# %%
table_city_brand = df_31.pivot_table(index="시군구명", columns="브랜드명", values="상호명", aggfunc="count")
table_city_brand.head()
# Out:
# 브랜드명  던킨도너츠  배스킨라빈스
# 시군구명
# 강남구     7.0    18.0
# 강동구     5.0    12.0
# 강북구     NaN     7.0
# 강서구     7.0    17.0
# 관악구     3.0    11.0

# %%
for i, val in table_city_brand.iterrows():
    dunkin = val["던킨도너츠"]
    baskin = val["배스킨라빈스"]
    print(i,':',dunkin, baskin)
# Out:
# 강남구 : 7.0 18.0
# 강동구 : 5.0 12.0
# 강북구 : nan 7.0
# 강서구 : 7.0 17.0
# 관악구 : 3.0 11.0
# 광진구 : 6.0 12.0
# 구로구 : 5.0 15.0
# 금천구 : 2.0 10.0
# 노원구 : 5.0 15.0
# 도봉구 : 2.0 8.0
# 동대문구 : 4.0 7.0
# 동작구 : 5.0 11.0
# 마포구 : 4.0 11.0
# 서대문구 : 4.0 10.0
# 서초구 : 11.0 16.0
# 성동구 : 2.0 7.0
# 성북구 : 1.0 14.0
# 송파구 : 6.0 22.0
# 양천구 : 3.0 13.0
# 영등포구 : 5.0 14.0
# 용산구 : 3.0 7.0
# 은평구 : 4.0 11.0
# 종로구 : 3.0 6.0
# 중구 : 6.0 6.0
# 중랑구 : 1.0 11.0

# %%
plt.figure(figsize=(15, 4))
g = sns.countplot(data=df_31, x="시군구명", hue="브랜드명", order=table_city_brand.index)

index_no = 0
for i, val in table_city_brand.iterrows():
    dunkin = val["던킨도너츠"]
    baskin = val["배스킨라빈스"]
    if pd.notna(dunkin) and pd.notna(baskin):
        g.text(x=index_no, y=dunkin, s=int(dunkin))
        g.text(x=index_no, y=baskin, s=int(baskin))
    index_no += 1

plt.show()

# %%
df_31[["위도", "경도"]].plot.scatter(x="경도", y="위도");   # 산점도(scatter plot)

# %%
sns.scatterplot(data=df_31, x="경도", y="위도", hue="브랜드명");

# %% [markdown]
# https://python-visualization.github.io/folium/latest/user_guide/map.html

# %% [markdown]
# 지도 시각화를 위한 라이브러리
# pip install folium

# %%
import folium

# %%
# 지도의 중심을 지정하기 위해 위도와 경도의 평균을 구합니다. 
lat = df_31["위도"].mean()
long = df_31["경도"].mean()
lat, long
# Out:
# (37.544168099384144, 126.9905536972075)

# %%
folium.Map(
    location=(lat, long),
    control_scale=True,
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e46792508e9ba9430632bca16121d6e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e46792508e9ba9430632bca16121d6e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e46792508e9ba9430632bca16121d6e9 = L.map(
#                 &quot;map_e46792508e9ba9430632bca16121d6e9&quot;,
#                 {
#                     center: [37.544168099384144, 126.9905536972075],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e46792508e9ba9430632bca16121d6e9);
#
#
#
#
#
#             var tile_layer_0b8c2ff54e6eceb94fd26569c301d855 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0b8c2ff54e6eceb94fd26569c301d855.addTo(map_e46792508e9ba9430632bca16121d6e9);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
m = folium.Map([lat, long])

folium.Marker(
    [37.495593, 127.039032], 
    popup='<i>던킨도너츠</i>', 
    tooltip="던킨도너츠").add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_26a230d2c8a50ad14bbe48d6785144f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_26a230d2c8a50ad14bbe48d6785144f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_26a230d2c8a50ad14bbe48d6785144f0 = L.map(
#                 &quot;map_26a230d2c8a50ad14bbe48d6785144f0&quot;,
#                 {
#                     center: [37.544168099384144, 126.9905536972075],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9ae9aa9ee201d119f9aaa2412f9657c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e9ae9aa9ee201d119f9aaa2412f9657c.addTo(map_26a230d2c8a50ad14bbe48d6785144f0);
#
#
#             var marker_53fcd28a21792560ed959363087286bf = L.marker(
#                 [37.495593, 127.039032],
#                 {}
#             ).addTo(map_26a230d2c8a50ad14bbe48d6785144f0);
#
#
#         var popup_bc6ef10aa89a241b854c0c243cddf302 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd755bb2956c66e165ca7f21a5f4229f = $(`&lt;div id=&quot;html_bd755bb2956c66e165ca7f21a5f4229f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;던킨도너츠&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_bc6ef10aa89a241b854c0c243cddf302.setContent(html_bd755bb2956c66e165ca7f21a5f4229f);
#
#
#
#         marker_53fcd28a21792560ed959363087286bf.bindPopup(popup_bc6ef10aa89a241b854c0c243cddf302)
#         ;
#
#
#
#
#             marker_53fcd28a21792560ed959363087286bf.bindTooltip(
#                 `&lt;div&gt;
#                      던킨도너츠
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             tile_layer_e9ae9aa9ee201d119f9aaa2412f9657c.addTo(map_26a230d2c8a50ad14bbe48d6785144f0);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# pip install git+https://github.com/python-visualization/branca.git@master

# %%
df_31.index
# Out:
# Index([  1970,   4826,   8942,   9497,   9808,  10404,  11947,  14264,  14622,
#         15262,
#        ...
#        454430, 454626, 459262, 461924, 465005, 465455, 468834, 472939, 473619,
#        473837],
#       dtype='int64', length=395)

# %%
m = folium.Map([lat, long], zoom_start=12)

for i in df_31.index:
    
    sub_lat = df_31.loc[i, "위도"]
    sub_long = df_31.loc[i, "경도"]
    title = df_31.loc[i, "상호명"] + " - " + df_31.loc[i, "도로명주소"]
    
    icon_color = "blue"
    if df_31.loc[i, "브랜드명"] == "던킨도너츠":
        icon_color = "red"
    
    folium.Marker(
        [sub_lat, sub_long], 
        icon=folium.Icon(color=icon_color),
        popup=f'<i>{title}</i>', 
        tooltip=title).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ba433c0596c5d442895b042a8934b44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ba433c0596c5d442895b042a8934b44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ba433c0596c5d442895b042a8934b44 = L.map(
#                 &quot;map_6ba433c0596c5d442895b042a8934b44&quot;,
#                 {
#                     center: [37.544168099384144, 126.9905536972075],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_613ee06d04d82878bee1a823d7f7a9e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_613ee06d04d82878bee1a823d7f7a9e0.addTo(map_6ba433c0596c5d442895b042a8934b44);
#
#
#             var marker_495ebf08b160d3b5169be0716f7aab96 = L.marker(
#                 [37.5350040176971, 127.010578694056],
#                 {}
#             ).addTo(map_6ba433c0596c5d442895b042a8934b44);
#
#
#             var icon_4f4639a2b8648e2b4efad320c91148f5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_495ebf08b160d3b5169be0716f7aab96.setIcon(icon_4f4639a2b8648e2b4efad320c91148f5);
#
#
#         var popup_9d188aa64d8a070241eab7d90739c8f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5cf738828d353150ebbaf44dc2bf96f9 = $(`&lt;div id=&quot;html_5cf738828d353150ebbaf44dc2bf96f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;비알배스킨라빈스한남HIVE - 서울특별시 용산구 독서당로 93&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_9d188aa64d8a070241eab7d90739c8f1.setContent(html_5cf738828d353150ebbaf44dc2bf96f9);
#
#
#
#         marker_495ebf08b160d3b5169be0716f7aab96.bindPopup(popup_9d188aa64d8a070241eab7d90739c8f1)
#         ;
#
#
#
#
#             marker_495ebf08b160d3b5169be0716f7aab96.bindTooltip(
#                 `&lt;div&gt;
#                      비알배스킨라빈스한남HIVE - 서울특별시 용산구 독서당로 93
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d1b7769762e674cdf12ee1fa414437a0 = L.marker(
#                 [37.5185366105608, 126.976135156198],
#                 {}
#             ).addTo(map_6ba433c0596c5d442895b042a8934b44);
#
#
#             var icon_2188982fa0ae3be8fe37de32b84cdc64 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1b7769762e674cdf12ee1fa414437a0.setIcon(icon_2188982fa0ae3be8fe37de32b84cdc64);
#
#
#         var popup_405e9f729e6e8d3151c70fd8d89d4719 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_41e421f8cfaa13a8800dc0eec72bc9ec = $(`&lt;div id=&quot;html_41e421f8cfaa13a8800dc0eec72bc9ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;비알배스킨라빈스동부이촌점 - 서울특별시 용산구 이촌로 260&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_405e9f729e6e8d3151c70fd8d89d4719.setContent(html_41e421f8cfaa13a8800dc0eec72bc9ec);
#
#
#
#         marker_d1b7769762e674cdf12ee1fa414437a0.bindPopup(popup_405e9f729e6e8d3151c70fd8d89d4719)
#         ;
#
#
#
#
#             marker_d1b7769762e674cdf12ee1fa414437a0.bindTooltip(
#                 `&lt;div&gt;
#                      비알배스킨라빈스동부이촌점 - 서울특별시 용산구 이촌로 260
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c612f44e8a98f4f285ce80efb020c861 = L.marker(
#                 [37.6598021754275, 127.073221344673],
#                 {}
#             ).addTo(map_6ba433c0596c5d442895b042a8934b44);
#
#
#             var icon_c42f4c6e5ea851d6736a1072382b0d5b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c612f44e8a98f4f285ce80efb020c861.setIcon(icon_c42f4c6e5ea851d6736a1072382b0d5b);
#
#
#         var popup_0e5e1fd52bc74ba318ec0baf8d87df01 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1f4d3033c26b93ddfd13eb93842a91b4 = $(`&lt;div id=&quot;html_1f4d3033c26b93ddfd13eb93842a91b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;배스킨라빈스상계역점 - 서울특별시 노원구 한글비석로 384&lt;/i&gt;&lt;/div&gt;`)[0];

# %%
from folium.plugins import MarkerCluster

m = folium.Map([lat, long], zoom_start=12)
marker_cluster = MarkerCluster().add_to(m)

for i in df_31.index:
    
    sub_lat = df_31.loc[i, "위도"]
    sub_long = df_31.loc[i, "경도"]
    title = df_31.loc[i, "상호명"] + " - " + df_31.loc[i, "도로명주소"]
    
    icon_color = "blue"
    if df_31.loc[i, "브랜드명"] == "던킨도너츠":
        icon_color = "red"
    
    folium.Marker(
        [sub_lat, sub_long], 
        icon=folium.Icon(color=icon_color),
        popup=f'<i>{title}</i>', 
        tooltip=title).add_to(marker_cluster)

m.save('index.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_930f53f1707cfcb3093ada17a37a4340 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_930f53f1707cfcb3093ada17a37a4340&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_930f53f1707cfcb3093ada17a37a4340 = L.map(
#                 &quot;map_930f53f1707cfcb3093ada17a37a4340&quot;,
#                 {
#                     center: [37.544168099384144, 126.9905536972075],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_682d58e9761fb78681fae1058500ecd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_682d58e9761fb78681fae1058500ecd0.addTo(map_930f53f1707cfcb3093ada17a37a4340);
#
#
#             var marker_cluster_a8881434df71069138d77d202af128b7 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             var marker_1f457bc8406fccf3b4e2fc2e074f3758 = L.marker(
#                 [37.5350040176971, 127.010578694056],
#                 {}
#             ).addTo(marker_cluster_a8881434df71069138d77d202af128b7);
#
#
#             var icon_f8085b312b7cb2baa4fcae67e75df615 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_1f457bc8406fccf3b4e2fc2e074f3758.setIcon(icon_f8085b312b7cb2baa4fcae67e75df615);
#
#
#         var popup_fe4fa822ae58e51611ebd3ac70356ad3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d48d50d047e79edf23a1b212cd04b2b6 = $(`&lt;div id=&quot;html_d48d50d047e79edf23a1b212cd04b2b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;비알배스킨라빈스한남HIVE - 서울특별시 용산구 독서당로 93&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_fe4fa822ae58e51611ebd3ac70356ad3.setContent(html_d48d50d047e79edf23a1b212cd04b2b6);
#
#
#
#         marker_1f457bc8406fccf3b4e2fc2e074f3758.bindPopup(popup_fe4fa822ae58e51611ebd3ac70356ad3)
#         ;
#
#
#
#
#             marker_1f457bc8406fccf3b4e2fc2e074f3758.bindTooltip(
#                 `&lt;div&gt;
#                      비알배스킨라빈스한남HIVE - 서울특별시 용산구 독서당로 93
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_a55e6c083c7c02889bbde7269db1d4c5 = L.marker(
#                 [37.5185366105608, 126.976135156198],
#                 {}
#             ).addTo(marker_cluster_a8881434df71069138d77d202af128b7);
#
#
#             var icon_798bbc97551b2d214c3bfbaaf3c1f6e0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_a55e6c083c7c02889bbde7269db1d4c5.setIcon(icon_798bbc97551b2d214c3bfbaaf3c1f6e0);
#
#
#         var popup_f3b79e6766139a7f9eff9dbeddc8773b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6666f4bc866b98aeef9d590cb723d452 = $(`&lt;div id=&quot;html_6666f4bc866b98aeef9d590cb723d452&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;i&gt;비알배스킨라빈스동부이촌점 - 서울특별시 용산구 이촌로 260&lt;/i&gt;&lt;/div&gt;`)[0];
#                 popup_f3b79e6766139a7f9eff9dbeddc8773b.setContent(html_6666f4bc866b98aeef9d590cb723d452);
#
#
#
#         marker_a55e6c083c7c02889bbde7269db1d4c5.bindPopup(popup_f3b79e6766139a7f9eff9dbeddc8773b)
#         ;
#
#
#
#
#             marker_a55e6c083c7c02889bbde7269db1d4c5.bindTooltip(
#                 `&lt;div&gt;
#                      비알배스킨라빈스동부이촌점 - 서울특별시 용산구 이촌로 260
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_d72b6ee58e8ef29cadc2b4951510d1dc = L.marker(
#                 [37.6598021754275, 127.073221344673],
#                 {}
#             ).addTo(marker_cluster_a8881434df71069138d77d202af128b7);
#
#
#             var icon_a531e1e5e7849ce2cb3b96aea0979315 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;whi
